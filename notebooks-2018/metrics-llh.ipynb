# %%
import sys
import os
sys.path = [os.path.abspath('../')] + sys.path

os.environ['OMP_NUM_THREADS'] = '1'
os.environ['OPENBLAS_NUM_THREADS'] = '1'

from experiments.plot_hawkes import plot_coeffs, plot_ticks_hist
from experiments.hawkes_coeffs import get_coeffs_dim_30, get_coeffs_dim_100, retrieve_coeffs
from experiments.simulation import simulate_and_save_hawkes, simulate_hawkes_in_parallel
from experiments.weights_computation import pre_compute_hawkes, LEAST_SQ_LOSS, LLH_LOSS
from experiments.learning import find_best_metrics

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# /home/m.bompaire/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
from multiprocessing import cpu_count

dim = 30
run_times = [500, 1000, 2000, 3000, 5000]

n_simulations = 10
n_cpu = cpu_count() - 1

directory_path = '/home/m.bompaire/experiments/hawkes_data/'
#directory_path = '/home/m.bompaire/experiments/hawkes_data_v2_2nd/'
#directory_path = '/home/m.bompaire/experiments/hawkes_data_v3/'

n_decays = 3

# %%
# simulate_hawkes_in_parallel(dim, run_times, n_decays, n_simulations, directory_path, n_cpu=n_cpu)

# %%
# max_pre_computed_hawkes = 10
# 
# for run_time in run_times:
#     pre_compute_hawkes(dim, run_time, n_decays, max_pre_computed_hawkes, 
#                        directory_path, n_cpu=n_cpu, loss=LLH_LOSS)

# %%
from collections import OrderedDict

from experiments.report_utils import read_lambdas_csv

from experiments.tested_prox import (
    create_prox_l1_no_mu, create_prox_l1w_no_mu,
    create_prox_l1_no_mu_nuclear, create_prox_l1w_no_mu_nuclear,
    create_prox_nuclear
)

prox_infos = OrderedDict()

prox_infos['l1'] = {
    'n_initial_points': 5,
    'max_relative_step': 2,
    'create_prox': create_prox_l1_no_mu,
    'tol': 1e-6,
    'dim': 1,
}

prox_infos['l1w'] = {
    'n_initial_points': 5,
    'max_relative_step': 2,
    'create_prox': create_prox_l1w_no_mu,
    'tol': 1e-6,
    'dim': 1,
}

#prox_infos['nuclear'] = {
#    'n_initial_points': 3,
#    'max_relative_step': 2,
#    'create_prox': create_prox_nuclear,
#    'tol': 1e-7,
#    'dim': 1,
#}
#
# prox_infos['l1_nuclear'] = {
#     'n_initial_points': 3,
#     'max_relative_step': 5,
#     'create_prox': create_prox_l1_no_mu_nuclear,
#     'tol': 1e-7,
#     'dim': 2,
# }
# 
# prox_infos['l1w_nuclear'] = {
#     'n_initial_points': 3,
#     'max_relative_step': 5,
#     'create_prox': create_prox_l1w_no_mu_nuclear,
#     'tol': 1e-7,
#     'dim': 2,
# }

def get_nuclear_strength_as_initial_points(suffix, model_file_paths):
    lambdas_df = read_lambdas_csv(suffix, [])
    prox_lambdas_df = lambdas_df[lambdas_df['prox'] == 'nuclear']
    
    initial_points_dict = {}
    for _, row in prox_lambdas_df.iterrows():
        end_time = int(row['end_time'])
        best_lambdas_str = row[['alpha_auc', 'alphas_auc_no_diag', 'estimation_error', 'estimation_error_no_diag','kendall', 'kendall_no_diag']].values
        best_lambdas = sorted(list(set([float(l) for l in best_lambdas_str])))
        initial_points_dict[end_time] = best_lambdas
        
    end_time = int(model_file_paths[0].split('T_')[1].split('/')[0])
    return initial_points_dict[end_time]

# get_nuclear_strength_as_initial_points('v3_10_models-Copy1', ['/home/m.bompaire/experiments/hawkes_data_v3/train_hawkes/dim_30/u=3/T_10000/precomputed/precomputed_000.pkl'])

# prox_infos['dedicated_l1w_nuclear_1d'] = {
#     'initial_points': get_nuclear_strength_as_initial_points,
#     'n_initial_points': 5,
#     'max_relative_step': 2,
#     'create_prox': create_prox_l1w_no_mu_nuclear,
#     'tol': 1e-8,
#     'dim': 2,
#     'mode': 'dedicated',
#     'dim_1_n_extra_initial_points': 2,
# }
# 
# prox_infos['dedicated_l1_nuclear_1d'] = {
#     'initial_points': get_nuclear_strength_as_initial_points,
#     'n_initial_points': 5,
#     'max_relative_step': 2,
#     'create_prox': create_prox_l1_no_mu_nuclear,
#     'tol': 1e-8,
#     'dim': 2,
#     'mode': 'dedicated',
#     'dim_1_n_extra_initial_points': 2,
# }

prox_infos = OrderedDict(
    (prox_name, dict(name=prox_name, **prox_info)) for prox_name, prox_info in prox_infos.items())
list(prox_infos.keys())
# Out:
# ['l1', 'l1w']

# %%
directory_path
# Out:
# '/home/m.bompaire/experiments/hawkes_data/'

# %%
n_models = 30

solver_kwargs = {'tol': 1e-6, 'max_iter': 25000, 'step': 1e-2}


if False:
    n_simulations = n_models

    simulate_hawkes_in_parallel(dim, run_times, n_decays, n_simulations, directory_path, n_cpu=n_cpu)

    max_pre_computed_hawkes = n_models

    for run_time in run_times:
        pre_compute_hawkes(dim, run_time, n_decays, max_pre_computed_hawkes, 
                           directory_path, n_cpu=n_cpu, loss=LLH_LOSS)


keep_prox = ['l1', 'l1w']
for run_time in run_times:
    for prox_info in prox_infos.values():
        if prox_info['name'] not in keep_prox:
            continue
        infos = find_best_metrics(
            dim, run_time, n_decays, n_models, prox_info, solver_kwargs,
            directory_path, max_run_count=5, n_cpu=n_cpu, suffix='v1_llh_30_models', first_prox=keep_prox[0],
            loss=LLH_LOSS)
# Out:
# ## For time 500
# ### For prox l1
# coeffs file existed already and was the same
# Retrieved 30 precomputed models
# 2020-02-23 10:26 Run 0 - With 6 new points
# 5.9401806995373e-05 0.001 True
# 2020-02-23 10:31 - did not converge train=1 strength=0, stopped at 5.94e-05 for tol=1e-06, took 255s, with step 0.01
# 5.928924366323659e-05 0.001 True
# 2020-02-23 10:31 - did not converge train=8 strength=0, stopped at 5.93e-05 for tol=1e-06, took 258s, with step 0.01
# 5.946556439681649e-05 0.001 True
# 2020-02-23 10:31 - did not converge train=26 strength=0, stopped at 5.95e-05 for tol=1e-06, took 260s, with step 0.01
# 5.8972415579746665e-05 0.001 True
# 2020-02-23 10:31 - did not converge train=20 strength=0, stopped at 5.9e-05 for tol=1e-06, took 264s, with step 0.01
# 5.9408262632241216e-05 0.001 True
# 2020-02-23 10:31 - did not converge train=18 strength=0, stopped at 5.94e-05 for tol=1e-06, took 264s, with step 0.01
# 5.924635089289785e-05 0.001 True
# 2020-02-23 10:31 - did not converge train=12 strength=0, stopped at 5.92e-05 for tol=1e-06, took 265s, with step 0.01
# 5.867434815427573e-05 0.001 True
# 2020-02-23 10:31 - did not converge train
-05 0.001 True
# 2020-02-23 10:35 - did not converge train=18 strength=1e-09, stopped at 5.94e-05 for tol=1e-06, took 265s, with step 0.01
# 5.897241560962683e-05 0.001 True
# 2020-02-23 10:35 - did not converge train=20 strength=1e-09, stopped at 5.9e-05 for tol=1e-06, took 267s, with step 0.01
# 5.896848470843874e-05 0.001 True
# 2020-02-23 10:35 - did not converge train=0 strength=1e-09, stopped at 5.9e-05 for tol=1e-06, took 266s, with step 0.01
# 5.9246350914774196e-05 0.001 True
# 2020-02-23 10:35 - did not converge train=12 strength=1e-09, stopped at 5.92e-05 for tol=1e-06, took 268s, with step 0.01
# 5.917149300988798e-05 0.001 True
# 2020-02-23 10:35 - did not converge train=10 strength=1e-09, stopped at 5.92e-05 for tol=1e-06, took 269s, with step 0.01
# 5.896333400141329e-05 0.001 True
# 2020-02-23 10:35 - did not converge train=4 strength=1e-09, stopped at 5.9e-05 for tol=1e-06, took 269s, with step 0.01
# 5.86743481881436e-05 0.001 True
# 2020-02-23 10:35 - did not converge train=14 strength=1e-09, stopped at 5.87e-05 for tol=1e-06, took 269s, with step 0.00599
# 5.930284573289932e-05 0.001 True
# 2020-02-23 10:35 - did not converge train=27 strength=1e-09, stopped at 5.93e-05 for tol=1e-06, took 270s, with step 0.01
# 5.91782990960191e-05 0.001 True
# 2020-02-23 10:35 - did not converge train=25 strength=1e-09, stopped at 5.92e-05 for tol=1e-06, took 271s, with step 0.00599
# 5.085425664845405e-05 0.001 True
# 2020-02-23 10:35 - did not converge train=22 strength=1e-09, stopped at 5.09e-05 for tol=1e-06, took 271s, with step 0.000464
# 5.904539198523774e-05 0.001 True
# 2020-02-23 10:36 - did not converge train=2 strength=1e-09, stopped at 5.9e-05 for tol=1e-06, took 273s, with step 0.01
# 5.857932822696104e-05 0.001 True
# 2020-02-23 10:36 - did not converge train=13 strength=1e-09, stopped at 5.86e-05 for tol=1e-06, took 273s, with step 0.00599
# 5.930191128338726e-05 0.001 True
# 2020-02-23 10:36 - did not converge train=3 strength=1e-09, stopped at 5.93e-05 for tol=1e-06, took 274s, with step 0.01
# 5.895568975321675e-05 0.001 True
# 2020-02-23 10:36 - did not converge train=17 strength=1e-09, stopped at 5.9e-05 for tol=1e-06, took 275s, with step 0.00599
# 5.7230590116208624e-05 0.001 True
# 2020-02-23 10:36 - did not converge train=24 strength=1e-09, stopped at 5.72e-05 for tol=1e-06, took 276s, with step 0.00215
# 5.9065815946671114e-05 0.001 True
# 2020-02-23 10:36 - did not converge train=16 strength=1e-09, stopped at 5.91e-05 for tol=1e-06, took 276s, with step 0.01
# 5.890005120484384e-05 0.001 True
# 2020-02-23 10:36 - did not converge train=15 strength=1e-09, stopped at 5.89e-05 for tol=1e-06, took 276s, with step 0.01
# 5.92589431456479e-05 0.001 True
# 2020-02-23 10:36 - did not converge train=11 strength=1e-09, stopped at 5.93e-05 for tol=1e-06, took 283s, with step 0.01
# 5.898573914518943e-05 0.001 True
# 2020-02-23 10:36 - did not converge train=9 strength=1e-09, stopped at 5.9e-05 for tol=1e-06, took 277s, with step 0.01
# 5.923117723908649e-05 0.001 True
# 2020-02-23 10:36 - did not converge train=19 strength=1e-09, stopped at 5.92e-05 for tol=1e-06, took 279s, with step 0.01
# 5.9134496225886194e-05 0.001 True
# 2020-02-23 10:36 - did not converge train=29 strength=1e-09, stopped at 5.91e-05 for tol=1e-06, took 279s, with step 0.01
# 5.868197818497278e-05 0.001 True
# 2020-02-23 10:36 - did not converge train=28 strength=1e-09, stopped at 5.87e-05 for tol=1e-06, took 282s, with step 0.01
# 5.8993017404964496e-05 0.001 True
# 2020-02-23 10:36 - did not converge train=23 strength=1e-09, stopped at 5.9e-05 for tol=1e-06, took 282s, with step 0.01
# 5.9152417948625814e-05 0.001 True
# 2020-02-23 10:36 - did not converge train=21 strength=1e-09, stopped at 5.92e-05 for tol=1e-06, took 285s, with step 0.01
# 5.946035924947812e-05 0.001 True
# 2020-02-23 10:36 - did not converge train=6 strength=1e-09, stopped at 5.95e-05 for tol=1e-06, took 292s, with step 0.01
# 5.8969124692448957e-05 0.001 True
# 2020-02-23 10:36 - did not converge train=5 strength=1e-09, stopped at 5.9e-05 for tol=1e-06, took 291s, with step 0.01
# 5.895976511820717e-05 0.001 True
# 2020-02-23 10:36 - did not converge train=7 strength=1e-09, stopped at 5.9e-05 for tol=1e-06, took 292s, with step 0.01
# 5.940180733381198e-05 0.001 True
# 2020-02-23 10:39 - did not converge train=1 strength=1.78e-08, stopped at 5.94e-05 for tol=1e-06, took 242s, with step 0.01
# 5.946556466791118e-05 0.001 True
# 2020-02-23 10:39 - did not converge train=26 strength=1.78e-08, stopped at 5.95e-05 for tol=1e-06, took 245s, with step 0.01
# 5.940826290737804e-05 0.001 True
# 2020-02-23 10:39 - did not converge train=18 strength=1.78e-08, stopped at 5.94e-05 for tol=1e-06, took 241s, with step 0.01
# 5.89684852075287e-05 0.001 True
# 2020-02-23 10:39 - did not converge train=0 strength=1.78e-08, stopped at 5.9e-05 for tol=1e-06, took 239s, with step 0.01
# 5.928924399962132e-05 0.001 True
# 2020-02-23 10:39 - did not converge train=8 strength=1.78e-08, stopped at 5.93e-05 for tol=1e-06, took 243s, with step 0.01
# 5.9246351282088726e-05 0.001 True
# 2020-02-23 10:39 - did not converge train=12 strength=1.78e-08, stopped at 5.92e-05 for tol=1e-06, took 241s, with step 0.01
# 5.9171493432661355e-05 0.001 True
# 2020-02-23 10:39 - did not converge train=10 strength=1.78e-08, stopped at 5.92e-05 for tol=1e-06, took 242s, with step 0.01
# 5.897241611314739e-05 0.001 True
# 2020-02-23 10:39 - did not converge train=20 strength=1.78e-08, stopped at 5.9e-05 for tol=1e-06, took 247s, with step 0.01
# 5.867434875638135e-05 0.001 True
# 2020-02-23 10:39 - did not converge train=14 strength=1.78e-08, stopped at 5.87e-05 for tol=1e-06, took 249s, with step 0.00599
# 5.896333447097645e-05 0.001 True
# 2020-02-23 10:40 - did not converge train=4 strength=1.78e-08, stopped at 5.9e-05 for tol=1e-06, took 249s, with step 0.01
# 5.917829948745716e-05 0.001 True
# 2020-02-23 10:40 - did not converge train=25 strength=1.78e-08, stopped at 5.92e-05 for tol=1e-06, took 245s, with step 0.00599
# 5.9302846107626815e-05 0.001 True
# 2020-02-23 10:40 - did not converge train=27 strength=1.78e-08, stopped at 5.93e-05 for tol=1e-06, took 250s, with step 0.01
# 5.9045392396055795e-05 0.001 True
# 2020-02-23 10:40 - did not converge train=2 strength=1.78e-08, stopped at 5.9e-05 for tol=1e-06, took 245s, with step 0.01
# 5.8579328835403774e-05 0.001 True
# 2020-02-23 10:40 - did not converge train=13 strength=1.78e-08, stopped at 5.86e-05 for tol=1e-06, took 245s, with step 0.00599
# 5.9258943528825465e-05 0.001 True
# 2020-02-23 10:40 - did not converge train=11 strength=1.78e-08, stopped at 5.93e-05 for tol=1e-06, took 243s, with step 0.01
# 5.085426019760214e-05 0.001 True
# 2020-02-23 10:40 - did not converge train=22 strength=1.78e-08, stopped at 5.09e-05 for tol=1e-06, took 252s, with step 0.000464
# 5.9065816486212514e-05 0.001 True
# 2020-02-23 10:40 - did not converge train=16 strength=1.78e-08, stopped at 5.91e-05 for tol=1e-06, took 248s, with step 0.01
# 5.930191167172514e-05 0.001 True
# 2020-02-23 10:40 - did not converge train=3 strength=1.78e-08, stopped at 5.93e-05 for tol=1e-06, took 254s, with step 0.01
# 5.8955690260214296e-05 0.001 True
# 2020-02-23 10:40 - did not converge train=17 strength=1.78e-08, stopped at 5.9e-05 for tol=1e-06, took 255s, with step 0.00599
# 5.723059148993471e-05 0.001 True
# 2020-02-23 10:40 - did not converge train=24 strength=1.78e-08, stopped at 5.72e-05 for tol=1e-06, took 255s, with step 0.00215
# 5.8900051694724356e-05 0.001 True
# 2020-02-23 10:40 - did not converge train=15 strength=1.78e-08, stopped at 5.89e-05 for tol=1e-06, took 255s, with step 0.01
# 5.923117767024207e-05 0.001 True
# 2020-02-23 10:40 - did not converge train=19 strength=1.78e-08, stopped at 5.92e-05 for tol=1e-06, took 250s, with step 0.01
# 5.913449673589583e-05 0.001 True
# 2020-02-23 10:40 - did not converge train=29 strength=1.78e-08, stopped at 5.91e-05 for tol=1e-06, took 250s, with step 0.01
# 5.8985739702331165e-05 0.001 True
# 2020-02-23 10:40 - did not converge train=9 strength=1.78e-08, stopped at 5.9e-05 for tol=1e-06, took 256s, with step 0.01
# 5.899301790228422e-05 0.001 True
# 2020-02-23 10:40 - did not converge train=23 strength=1.78e-08, stopped at 5.9e-05 for tol=1e-06, took 253s, with step 0.01
# 5.868197880460036e-05 0.001 True
# 2020-02-23 10:40 - did not converge train=28 strength=1.78e-08, stopped at 5.87e-05 for tol=1e-06, took 258s, with step 0.01
# 5.915241838733156e-05 0.001 True
# 2020-02-23 10:40 - did not converge train=21 strength=1.78e-08, stopped at 5.92e-05 for tol=1e-06, took 255s, with step 0.01
# 5.896912523141635e-05 0.001 True
# 2020-02-23 10:40 - did not converge train=5 strength=1.78e-08, stopped at 5.9e-05 for tol=1e-06, took 259s, with step 0.01
# 5.946035961771245e-05 0.001 True
# 2020-02-23 10:40 - did not converge train=6 strength=1.78e-08, stopped at 5.95e-05 for tol=1e-06, took 264s, with step 0.01
# 5.8959765767757245e-05 0.001 True
# 2020-02-23 10:41 - did not converge train=7 strength=1.78e-08, stopped at 5.9e-05 for tol=1e-06, took 262s, with step 0.01
